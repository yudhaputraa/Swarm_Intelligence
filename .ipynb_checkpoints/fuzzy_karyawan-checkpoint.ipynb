# %% [markdown]
# ---
# Fuzzy Tahani
# ---

# %%
# import library
import numpy as np
import pandas as pd

# %%
data_karyawan = pd.read_csv("dataset/karyawan.csv")
data_karyawan
# Out:
#     NIP  Nama  Umur  Masa Kerja  Gaji
# 0  ID01   Lia    30           6   750
# 1  ID02  Iwan    48          17  1500
# 2  ID03  Sari    36          14  1255
# 3  ID04  Andi    37           4  1040
# 4  ID05  Budi    42          12   950
# 5  ID06  Amir    39          13  1600
# 6  ID07  Rian    37           5  1250
# 7  ID08  Kiki    32           1   550
# 8  ID09  Alda    35           3   735
# 9  ID10  Yoga    25           2   860

# %%
# data umur
data_umur = np.array(data_karyawan)
data_umur = data_umur[:,[0,2]]
print("index = 0 Id karyawan, 1 = umur")
pd.DataFrame(data_umur)
# Out:
# index = 0 Id karyawan, 1 = umur
#       0   1
# 0  ID01  30
# 1  ID02  48
# 2  ID03  36
# 3  ID04  37
# 4  ID05  42
# 5  ID06  39
# 6  ID07  37
# 7  ID08  32
# 8  ID09  35
# 9  ID10  25

# %%
# Data masa kerja
data_masa_kerja = np.array(data_karyawan)
data_masa_kerja = data_masa_kerja[:,[0,3]]
print("index = 0 id Karyawan, 1 = masa kerja ")
pd.DataFrame(data_masa_kerja)
# Out:
# index = 0 id Karyawan, 1 = masa kerja
#       0   1
# 0  ID01   6
# 1  ID02  17
# 2  ID03  14
# 3  ID04   4
# 4  ID05  12
# 5  ID06  13
# 6  ID07   5
# 7  ID08   1
# 8  ID09   3
# 9  ID10   2

# %%
# Data gaji
data_gaji = np.array(data_karyawan)
data_gaji = data_gaji[:,[0,4]]
print("index = o id karyawan, 1 = gaji")
pd.DataFrame(data_gaji)
# Out:
# index = o id karyawan, 1 = gaji
#       0     1
# 0  ID01   750
# 1  ID02  1500
# 2  ID03  1255
# 3  ID04  1040
# 4  ID05   950
# 5  ID06  1600
# 6  ID07  1250
# 7  ID08   550
# 8  ID09   735
# 9  ID10   860

# %%
# umur
umur_01 = np.sum(data_umur[0:1,1], axis=0)
umur_02 = np.sum(data_umur[1:2,1], axis=0)
umur_03 = np.sum(data_umur[2:3,1], axis=0)
umur_04 = np.sum(data_umur[3:4,1], axis=0)
umur_05 = np.sum(data_umur[4:5,1], axis=0)
umur_06 = np.sum(data_umur[5:6,1], axis=0)
umur_07 = np.sum(data_umur[6:7,1], axis=0)
umur_08 = np.sum(data_umur[7:8,1], axis=0)
umur_09 = np.sum(data_umur[8:9,1], axis=0)
umur_10 = np.sum(data_umur[9:10,1], axis=0)
print("umur_01 :",umur_01)
print("umur_02 :",umur_02)
print("umur_03 :",umur_03)
print("umur_04 :",umur_04)
print("umur_05 :",umur_05)
print("umur_06 :",umur_06)
print("umur_07 :",umur_07)
print("umur_08 :",umur_08)
print("umur_09 :",umur_09)
print("umur_10 :",umur_10)
# Out:
# umur_01 : 30
# umur_02 : 48
# umur_03 : 36
# umur_04 : 37
# umur_05 : 42
# umur_06 : 39
# umur_07 : 37
# umur_08 : 32
# umur_09 : 35
# umur_10 : 25

# %%
# masa kerja
masa_kerja_01 = np.sum(data_masa_kerja[0:1,1], axis=0)
masa_kerja_02 = np.sum(data_masa_kerja[1:2,1], axis=0)
masa_kerja_03 = np.sum(data_masa_kerja[2:3,1], axis=0)
masa_kerja_04 = np.sum(data_masa_kerja[3:4,1], axis=0)
masa_kerja_05 = np.sum(data_masa_kerja[4:5,1], axis=0)
masa_kerja_06 = np.sum(data_masa_kerja[5:6,1], axis=0)
masa_kerja_07 = np.sum(data_masa_kerja[6:7,1], axis=0)
masa_kerja_08 = np.sum(data_masa_kerja[7:8,1], axis=0)
masa_kerja_09 = np.sum(data_masa_kerja[8:9,1], axis=0)
masa_kerja_10 = np.sum(data_masa_kerja[9:10,1], axis=0)

print("masa_kerja_01 :", masa_kerja_01)
print("masa_kerja_02 :", masa_kerja_02)
print("masa_kerja_03 :", masa_kerja_03)
print("masa_kerja_04 :", masa_kerja_04)
print("masa_kerja_05 :", masa_kerja_05)
print("masa_kerja_06 :", masa_kerja_06)
print("masa_kerja_07 :", masa_kerja_07)
print("masa_kerja_08 :", masa_kerja_08)
print("masa_kerja_09 :", masa_kerja_09)
print("masa_kerja_10 :", masa_kerja_10)
# Out:
# masa_kerja_01 : 6
# masa_kerja_02 : 17
# masa_kerja_03 : 14
# masa_kerja_04 : 4
# masa_kerja_05 : 12
# masa_kerja_06 : 13
# masa_kerja_07 : 5
# masa_kerja_08 : 1
# masa_kerja_09 : 3
# masa_kerja_10 : 2

# %%
# gaji
gaji_01 = np.sum(data_gaji[0:1,1], axis=0)
gaji_02 = np.sum(data_gaji[1:2,1], axis=0)
gaji_03 = np.sum(data_gaji[2:3,1], axis=0)
gaji_04 = np.sum(data_gaji[3:4,1], axis=0)
gaji_05 = np.sum(data_gaji[4:5,1], axis=0)
gaji_06 = np.sum(data_gaji[5:6,1], axis=0)
gaji_07 = np.sum(data_gaji[6:7,1], axis=0)
gaji_08 = np.sum(data_gaji[7:8,1], axis=0)
gaji_09 = np.sum(data_gaji[8:9,1], axis=0)
gaji_10 = np.sum(data_gaji[9:10,1], axis=0)

print("gaji_01 :", gaji_01)
print("gaji_02 :", gaji_02)
print("gaji_03 :", gaji_03)
print("gaji_04 :", gaji_04)
print("gaji_05 :", gaji_05)
print("gaji_06 :", gaji_06)
print("gaji_07 :", gaji_07)
print("gaji_08 :", gaji_08)
print("gaji_09 :", gaji_09)
print("gaji_10 :", gaji_10)
# Out:
# gaji_01 : 750
# gaji_02 : 1500
# gaji_03 : 1255
# gaji_04 : 1040
# gaji_05 : 950
# gaji_06 : 1600
# gaji_07 : 1250
# gaji_08 : 550
# gaji_09 : 735
# gaji_10 : 860

# %% [markdown]
# ---
# Model Fuzzy Tahani
# ---

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt

# %%
def RangeSubjektif(_low, _hig, _step):
    subjektif = np.arange(_low, _hig, _step)
    return subjektif

def AlgoritmaFuzzyYudha(_rule, _range_subjektif, _titel):
    lo = fuzz.trimf(_range_subjektif, _rule[0])
    mi = fuzz.trimf(_range_subjektif, _rule[1])
    hi = fuzz.trimf(_range_subjektif, _rule[2])
    fig, ax = plt.subplots(nrows=1, figsize=(6, 3))
    ax.plot(_range_subjektif, lo, 'b', linewidth=1.5, label = 'Low')
    ax.plot(_range_subjektif, mi, 'g', linewidth=1.5, label = 'middle')
    ax.plot(_range_subjektif, hi, 'r', linewidth=1.5, label = 'High')
    
    ax.set_title(_titel)
    ax.legend()
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
    plt.tight_layout()
    plt.show()
    
    return lo, mi, hi


def AlgoritmaFuzzyYudha2(_rule, _range_subjektif, _titel):
    mi = fuzz.trimf(_range_subjektif, _rule[0])
    hi = fuzz.trimf(_range_subjektif, _rule[1])
    
    fig, ax = plt.subplots(nrows=1, figsize=(6, 3))
    ax.plot(_range_subjektif, mi, 'g', linewidth=1.5, label = 'baru')
    ax.plot(_range_subjektif, hi, 'r', linewidth=1.5, label = 'lama')
    
    ax.set_title(_titel)
    ax.legend()
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    
    plt.tight_layout()
    plt.show()
    
    return mi, hi

# %%
xumur = RangeSubjektif(30, 50, 1)
rumur = np.array([
    [0, 30, 40],
    [35, 45, 50],
    [40, 50, 50]
])

xmasa_kerja = RangeSubjektif(5,25,1)
rmasa_kerja = np.array([
    [0, 5, 15],
    [10,25,25]
])

xgaji = RangeSubjektif(300, 2000, 1)
rgaji = np.array([
    [0, 300, 800],
    [500, 1000, 1500],
    [1000, 2000, 2000]
])

# untuk menampilkan grafik
lo_umur, mi_umur, hi_umur = AlgoritmaFuzzyYudha(rumur, xumur, 'umur')
mi_masa_kerja, hi_masa_kerja = AlgoritmaFuzzyYudha2(rmasa_kerja, xmasa_kerja, 'Masa Kerja')
lo_gaji, mi_gaji, hi_gaji = AlgoritmaFuzzyYudha(rgaji, xgaji, 'Gaji')

# %%
def FungsiKeanggotaan(_range, _lo, _mi, _hi, _nilai):
    lo = fuzz.interp_membership(_range, _lo, _nilai)
    mi = fuzz.interp_membership(_range, _mi, _nilai)
    hi = fuzz.interp_membership(_range, _hi, _nilai)
    
    return lo, mi, hi

def FungsiKeanggotaan2(_range, _mi, _hi, _nilai):
    mi = fuzz.interp_membership(_range, _mi, _nilai)
    hi = fuzz.interp_membership(_range, _hi, _nilai)
    
    return mi, hi

# %%
def Status(_keanggotaan):
    status = ""
    if _keanggotaan[0] > _keanggotaan[1] and _keanggotaan[0] > _keanggotaan[2]:
        status = "low"
    elif _keanggotaan[1] > _keanggotaan[0] and _keanggotaan[1] > _keanggotaan[2]:
        status = "medium"
    elif _keanggotaan[2] > _keanggotaan[0] and _keanggotaan[2] > _keanggotaan[1]:
        status = "high"
        
    return status

def Status2(_keanggotaan):
    status = ""
    if _keanggotaan[0] > _keanggotaan[1]:
        status = "low"
    elif _keanggotaan[1] > _keanggotaan[0]:
        status = "medium"
    
    return status

# %%
def RuleBase(_status_umur, _status_masa_kerja, _status_gaji):
    umur = _status_umur
    masa_kerja =  _status_masa_kerja
    gaji = _status_gaji
    
    karyawan = ""
    
    if umur == "low" and masa_kerja == "low" and gaji == "medium":
        karyawan = "karyawan Kontrak"
    elif umur == "high" and masa_kerja == "medium" and gaji == "high":
        karyawan = "karyawan tetap"
    elif umur == "low" and masa_kerja == "medium" and gaji == "medium":
        karyawan = "karyawan tetap"
    else:
        karyawan = "tidak diketahui"
        
    return karyawan

# %%
umur_angg_01 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_01)
umur_angg_02 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_02)
umur_angg_03 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_03)
umur_angg_04 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_04)
umur_angg_05 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_05)
umur_angg_06 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_06)
umur_angg_07 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_07)
umur_angg_08 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_08)
umur_angg_09 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_09)
umur_angg_10 = FungsiKeanggotaan(xumur, lo_umur, mi_umur, hi_umur, umur_10)

print("umur_angg_01 :", umur_angg_01)
print("umur_angg_02 :", umur_angg_02)
print("umur_angg_03 :", umur_angg_03)
print("umur_angg_04 :", umur_angg_04)
print("umur_angg_05 :", umur_angg_05)
print("umur_angg_06 :", umur_angg_06)
print("umur_angg_07 :", umur_angg_07)
print("umur_angg_08 :", umur_angg_08)
print("umur_angg_09 :", umur_angg_09)
print("umur_angg_10 :", umur_angg_10)

umur_sts_01 = Status(umur_angg_01)
umur_sts_02 = Status(umur_angg_02)
umur_sts_03 = Status(umur_angg_03)
umur_sts_04 = Status(umur_angg_04)
umur_sts_05 = Status(umur_angg_05)
umur_sts_06 = Status(umur_angg_06)
umur_sts_07 = Status(umur_angg_07)
umur_sts_08 = Status(umur_angg_08)
umur_sts_09 = Status(umur_angg_09)
umur_sts_10 = Status(umur_angg_10)

print("umur_sts_01 :", umur_sts_01)
print("umur_sts_02 :", umur_sts_02)
print("umur_sts_03 :", umur_sts_03)
print("umur_sts_04 :", umur_sts_04)
print("umur_sts_05 :", umur_sts_05)
print("umur_sts_06 :", umur_sts_06)
print("umur_sts_07 :", umur_sts_07)
print("umur_sts_08 :", umur_sts_08)
print("umur_sts_09 :", umur_sts_09)
print("umur_sts_10 :", umur_sts_10)
# Out:
# umur_angg_01 : (1.0, 0.0, 0.0)
# umur_angg_02 : (0.0, 0.4, 0.8)
# umur_angg_03 : (0.4, 0.1, 0.0)
# umur_angg_04 : (0.3, 0.2, 0.0)
# umur_angg_05 : (0.0, 0.7, 0.2)
# umur_angg_06 : (0.1, 0.4, 0.0)
# umur_angg_07 : (0.3, 0.2, 0.0)
# umur_angg_08 : (0.8, 0.0, 0.0)
# umur_angg_09 : (0.5, 0.0, 0.0)
# umur_angg_10 : (0.0, 0.0, 0.0)
# umur_sts_01 : low
# umur_sts_02 : high
# umur_sts_03 : low
# umur_sts_04 : low
# umur_sts_05 : medium
# umur_sts_06 : medium
# umur_sts_07 : low
# umur_sts_08 : low
# umur_sts_09 : low
# umur_sts_10 :

# %%
masa_kerja_angg_01 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_01)
masa_kerja_angg_02 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_02)
masa_kerja_angg_03 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_03)
masa_kerja_angg_04 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_04)
masa_kerja_angg_05 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_05)
masa_kerja_angg_06 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_06)
masa_kerja_angg_07 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_07)
masa_kerja_angg_08 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_08)
masa_kerja_angg_09 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_09)
masa_kerja_angg_10 =  FungsiKeanggotaan2(xmasa_kerja, mi_masa_kerja, hi_masa_kerja, masa_kerja_10)

print("masa_kerja_angg_01 :", masa_kerja_angg_01)
print("masa_kerja_angg_02 :", masa_kerja_angg_02)
print("masa_kerja_angg_03 :", masa_kerja_angg_03)
print("masa_kerja_angg_04 :", masa_kerja_angg_04)
print("masa_kerja_angg_05 :", masa_kerja_angg_05)
print("masa_kerja_angg_06 :", masa_kerja_angg_06)
print("masa_kerja_angg_07 :", masa_kerja_angg_07)
print("masa_kerja_angg_08 :", masa_kerja_angg_08)
print("masa_kerja_angg_09 :", masa_kerja_angg_09)
print("masa_kerja_angg_10 :", masa_kerja_angg_10)

masa_kerja_sts_01 = Status2(masa_kerja_angg_01)
masa_kerja_sts_02 = Status2(masa_kerja_angg_02)
masa_kerja_sts_03 = Status2(masa_kerja_angg_03)
masa_kerja_sts_04 = Status2(masa_kerja_angg_04)
masa_kerja_sts_05 = Status2(masa_kerja_angg_05)
masa_kerja_sts_06 = Status2(masa_kerja_angg_06)
masa_kerja_sts_07 = Status2(masa_kerja_angg_07)
masa_kerja_sts_08 = Status2(masa_kerja_angg_08)
masa_kerja_sts_09 = Status2(masa_kerja_angg_09)
masa_kerja_sts_10 = Status2(masa_kerja_angg_10)

print("masa kerja angg_01", masa_kerja_sts_01)
print("masa kerja angg_02", masa_kerja_sts_02)
print("masa kerja angg_03", masa_kerja_sts_03)
print("masa kerja angg_04", masa_kerja_sts_04)
print("masa kerja angg_05", masa_kerja_sts_05)
print("masa kerja angg_06", masa_kerja_sts_06)
print("masa kerja angg_07", masa_kerja_sts_07)
print("masa kerja angg_08", masa_kerja_sts_08)
print("masa kerja angg_09", masa_kerja_sts_09)
print("masa kerja angg_10", masa_kerja_sts_10)
# Out:
# masa_kerja_angg_01 : (0.9, 0.0)
# masa_kerja_angg_02 : (0.0, 0.4666666666666667)
# masa_kerja_angg_03 : (0.1, 0.26666666666666666)
# masa_kerja_angg_04 : (0.0, 0.0)
# masa_kerja_angg_05 : (0.3, 0.13333333333333333)
# masa_kerja_angg_06 : (0.2, 0.2)
# masa_kerja_angg_07 : (1.0, 0.0)
# masa_kerja_angg_08 : (0.0, 0.0)
# masa_kerja_angg_09 : (0.0, 0.0)
# masa_kerja_angg_10 : (0.0, 0.0)
# masa kerja angg_01 low
# masa kerja angg_02 medium
# masa kerja angg_03 medium
# masa kerja angg_04
# masa kerja angg_05 low
# masa kerja angg_06
# masa kerja angg_07 low
# masa kerja angg_08
# masa kerja angg_09
# masa kerja angg_10

# %%
gaji_angg_01 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_01)
gaji_angg_02 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_02)
gaji_angg_03 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_03)
gaji_angg_04 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_04)
gaji_angg_05 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_05)
gaji_angg_06 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_06)
gaji_angg_07 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_07)
gaji_angg_08 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_08)
gaji_angg_09 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_09)
gaji_angg_10 = FungsiKeanggotaan(xgaji, lo_gaji, mi_gaji, hi_gaji, gaji_10)


print("gaji_angg_01 :", gaji_angg_01)
print("gaji_angg_02 :", gaji_angg_02)
print("gaji_angg_03 :", gaji_angg_03)
print("gaji_angg_04 :", gaji_angg_04)
print("gaji_angg_05 :", gaji_angg_05)
print("gaji_angg_06 :", gaji_angg_06)
print("gaji_angg_07 :", gaji_angg_07)
print("gaji_angg_08 :", gaji_angg_08)
print("gaji_angg_09 :", gaji_angg_09)
print("gaji_angg_10 :", gaji_angg_10)

gaji_sts_01 = Status(gaji_angg_01)
gaji_sts_02 = Status(gaji_angg_02)
gaji_sts_03 = Status(gaji_angg_03)
gaji_sts_04 = Status(gaji_angg_04)
gaji_sts_05 = Status(gaji_angg_05)
gaji_sts_06 = Status(gaji_angg_06)
gaji_sts_07 = Status(gaji_angg_07)
gaji_sts_08 = Status(gaji_angg_08)
gaji_sts_09 = Status(gaji_angg_09)
gaji_sts_10 = Status(gaji_angg_10)

print("Gaji angg_01", gaji_sts_01)
print("Gaji angg_02", gaji_sts_02)
print("Gaji angg_03", gaji_sts_03)
print("Gaji angg_04", gaji_sts_04)
print("Gaji angg_05", gaji_sts_05)
print("Gaji angg_06", gaji_sts_06)
print("Gaji angg_07", gaji_sts_07)
print("Gaji angg_08", gaji_sts_08)
print("Gaji angg_09", gaji_sts_09)
print("Gaji angg_10", gaji_sts_10)
# Out:
# gaji_angg_01 : (0.1, 0.5, 0.0)
# gaji_angg_02 : (0.0, 0.0, 0.5)
# gaji_angg_03 : (0.0, 0.49, 0.255)
# gaji_angg_04 : (0.0, 0.92, 0.04)
# gaji_angg_05 : (0.0, 0.9, 0.0)
# gaji_angg_06 : (0.0, 0.0, 0.6)
# gaji_angg_07 : (0.0, 0.5, 0.25)
# gaji_angg_08 : (0.5, 0.1, 0.0)
# gaji_angg_09 : (0.13, 0.47, 0.0)
# gaji_angg_10 : (0.0, 0.72, 0.0)
# Gaji angg_01 medium
# Gaji angg_02 high
# Gaji angg_03 medium
# Gaji angg_04 medium
# Gaji angg_05 medium
# Gaji angg_06 high
# Gaji angg_07 medium
# Gaji angg_08 low
# Gaji angg_09 medium
# Gaji angg_10 medium

# %%
# rule based

status_karyawan_01 = RuleBase(umur_sts_01, masa_kerja_sts_01, gaji_sts_01)
status_karyawan_02 = RuleBase(umur_sts_02, masa_kerja_sts_02, gaji_sts_02)
status_karyawan_03 = RuleBase(umur_sts_03, masa_kerja_sts_03, gaji_sts_03)
status_karyawan_04 = RuleBase(umur_sts_04, masa_kerja_sts_04, gaji_sts_04)
status_karyawan_05 = RuleBase(umur_sts_05, masa_kerja_sts_05, gaji_sts_05)
status_karyawan_06 = RuleBase(umur_sts_06, masa_kerja_sts_06, gaji_sts_06)
status_karyawan_07 = RuleBase(umur_sts_07, masa_kerja_sts_07, gaji_sts_07)
status_karyawan_08 = RuleBase(umur_sts_08, masa_kerja_sts_08, gaji_sts_08)
status_karyawan_09 = RuleBase(umur_sts_09, masa_kerja_sts_09, gaji_sts_09)
status_karyawan_10 = RuleBase(umur_sts_10, masa_kerja_sts_10, gaji_sts_10)

print("status_karyawan_01 :", status_karyawan_01)
print("status_karyawan_02 :", status_karyawan_02)
print("status_karyawan_03 :", status_karyawan_03)
print("status_karyawan_04 :", status_karyawan_04)
print("status_karyawan_05 :", status_karyawan_01)
print("status_karyawan_06 :", status_karyawan_06)
print("status_karyawan_07 :", status_karyawan_07)
print("status_karyawan_08 :", status_karyawan_08)
print("status_karyawan_09 :", status_karyawan_09)
print("status_karyawan_10 :", status_karyawan_10)
# Out:
# status_karyawan_01 : karyawan Kontrak
# status_karyawan_02 : karyawan tetap
# status_karyawan_03 : tidak diketahui
# status_karyawan_04 : tidak diketahui
# status_karyawan_05 : karyawan Kontrak
# status_karyawan_06 : tidak diketahui
# status_karyawan_07 : karyawan Kontrak
# status_karyawan_08 : tidak diketahui
# status_karyawan_09 : tidak diketahui
# status_karyawan_10 : tidak diketahui
